# %%
from numpy import array

matrix1 = array([
    [2, 4],
    [1, 3]
])

matrix2 = array([
    [3, 1, 5],
    [-2, 1, 3]
])

matrix1 @ matrix2
# Out:
# array([[-2,  6, 22],
#        [-3,  4, 14]])

# %%
from torch import tensor

tensor(matrix1) @ tensor(matrix2)
# Out:
# tensor([[-2,  6, 22],
#         [-3,  4, 14]])
